# %%
import scipy.io as sio
data = sio.loadmat('data_train.mat', squeeze_me=True, struct_as_record=False)['data']
print(len(data))
# Out:
# 56511

# %%
data[0]._fieldnames
# Out:
# ['boundary',
#  'name',
#  'rType',
#  'rEdge',
#  'gtBox',
#  'gtBoxNew',
#  'order',
#  'rBoundary']

# %%
data[0].name
# Out:
# '57395'

# %%
data[0].rType
# Out:
# array([7, 3, 1, 9, 7, 3, 0, 2], dtype=int32)

# %%
data[0].rEdge
# Out:
# array([[0, 6, 2],
#        [0, 1, 3],
#        [1, 6, 2],
#        [1, 2, 3],
#        [2, 6, 2],
#        [2, 3, 0],
#        [3, 6, 6],
#        [3, 4, 1],
#        [4, 6, 7],
#        [4, 5, 9],
#        [5, 6, 4],
#        [6, 7, 1]], dtype=int32)
