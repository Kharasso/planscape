# %%
import os
import pickle
import joblib
import math
import hdbscan
import numpy as np
import pandas as pd
import polars as pl
from PIL import Image
from collections import Counter
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.cluster import Birch, AgglomerativeClustering
from sklearn.neighbors import KNeighborsClassifier
from sklearn.decomposition import PCA
import scipy.cluster.hierarchy as sch

# %%
df = pl.read_csv("nnary_features.csv")
df
# Out:
# shape: (80_787, 425)
# ┌───────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬──────────┐
# │ filename  ┆ uni_1_cou ┆ uni_1_tot ┆ uni_1_avg ┆ … ┆ tri_6_7_8 ┆ tri_6_7_8 ┆ tri_6_7_8 ┆ tri_6_7_ │
# │ ---       ┆ nt        ┆ al_area   ┆ _x        ┆   ┆ _area_rat ┆ _area_rat ┆ _avg_x    ┆ 8_avg_y  │
# │ str       ┆ ---       ┆ ---       ┆ ---       ┆   ┆ io_ij     ┆ io_jk     ┆ ---       ┆ ---      │
# │           ┆ f64       ┆ f64       ┆ f64       ┆   ┆ ---       ┆ ---       ┆ str       ┆ str      │
# │           ┆           ┆           ┆           ┆   ┆ str       ┆ str       ┆           ┆          │
# ╞═══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪══════════╡
# │ 40795.png ┆ 2.0       ┆ 3396.0    ┆ -38.60424 ┆ … ┆ null      ┆ null      ┆ null      ┆ null     │
# │ 60259.png ┆ null      ┆ null      ┆ null      ┆ … ┆ null      ┆ null      ┆ null      ┆ null     │
# │ 45409.png ┆ 2.0       ┆ 4462.0    ┆ -2.314433 ┆ … ┆ null      ┆ null      ┆ null      ┆ null     │
# │ 22733.png ┆ 1.0       ┆ 1855.0    ┆ 43.5      ┆ … ┆ null      ┆ null      ┆ null      ┆ null     │
# │ 25886.png ┆ 1.0       ┆ 1591.0    ┆ 72.5      ┆ … ┆ null      ┆ null      ┆ null      ┆ null     │
# │ …         ┆ …         ┆ …         ┆ …         ┆ … ┆ …         ┆ …         ┆ …         ┆ …        │
# │ 26753.png ┆ 1.0       ┆ 2135.5    ┆ 39.887224 ┆ … ┆ null      ┆ null      ┆ null      ┆ null     │
# │ 42387.png ┆ 1.0       ┆ 2378.0    ┆ -76.0     ┆ … ┆ null      ┆ null      ┆ null      ┆ null     │
# │ 19466.png ┆ 2.0       ┆ 3132.0    ┆ 49.873563 ┆ … ┆ null      ┆ null      ┆ null      ┆ null     │
# │ 32003.png ┆ 2.0       ┆ 4196.5    ┆ -19.65570 ┆ … ┆ null      ┆ null      ┆ null      ┆ null     │
# │           ┆           ┆           ┆ 5         ┆   ┆           ┆           ┆           ┆          │
# │ 76991.png ┆ 2.0       ┆ 4416.0    ┆ -103.1739 ┆ … ┆ null      ┆ null      ┆ null      ┆ null     │
# │           ┆           ┆           ┆ 13        ┆   ┆           ┆           ┆           ┆          │
# └───────────┴───────────┴───────────┴───────────┴───┴───────────┴───────────┴───────────┴──────────┘

# %%
df.shape
# Out:
# (80787, 425)

# %%
graphs = pickle.load(open("graphs.pkl", "rb"))

# %%
"3".split("e")
# Out:
# ['3']

# %%
all_types = [
    'common_room', 
    'master_room', 
    'living_room',  
    'balcony',       
    'bathroom',      
    'kitchen',     
    'storage',      
    'dining',        
]

G = 2
num_cells = G * G  
T = len(all_types)  
type_to_idx = {t: i for i, t in enumerate(all_types)}

print(f"Number of types T = {T}, grid per type = {G}×{G} ({num_cells} cells), total features = {T*num_cells}")
# Out:
# Number of types T = 8, grid per type = 2×2 (4 cells), total features = 32

# %%
def extract_feature_matrix(floorplans, all_types, G=16, image_size=256):
    N = len(floorplans)
    T = len(all_types)
    type_to_idx = {t: i for i, t in enumerate(all_types)}

    D_area   = T * G * G
    D_counts = T * G * G
    D_total  = D_area + D_counts


    X = np.zeros((N, D_total), dtype=float)
    filenames = [None] * N

    for i, fp in enumerate(floorplans):
        filenames[i] = fp["filename"]
        rooms = fp["rooms"]

        for room in rooms:
            rtype = room["type"]
            if rtype not in type_to_idx:
  
                continue
            t_idx = type_to_idx[rtype]

            cx_raw, cy_raw = room["centroid"]

            cx = np.clip(cx_raw / image_size, 0.0, 1.0 - 1e-9)
            cy = np.clip(cy_raw / image_size, 0.0, 1.0 - 1e-9)

            gx = int(cx * G)
            gy = int(cy * G)
            cell_idx = gy * G + gx

            norm_area = room["area"] / (image_size * image_size)
            X[i, t_idx * (G * G) + cell_idx] += norm_area


            X[i, D_area + t_idx * (G * G) + cell_idx] += 1.0

    return X, filenames


X_raw, filenames = extract_feature_matrix(graphs, all_types, G=G, image_size=256)
print("feature matrix shape:", X_raw.shape)
# Out:
# Raw feature‐matrix shape: (80788, 64)

# %%
def visualize_grid_indices(G=16, image_size=256):

    cell_size = image_size / G
    fig, ax = plt.subplots(figsize=(8, 8))


    for i in range(G + 1):
        x = i * cell_size
        ax.plot([x, x], [0, image_size], color='black', linewidth=0.5)  
        y = i * cell_size
        ax.plot([0, image_size], [y, y], color='black', linewidth=0.5) 

    for gy in range(G):
        for gx in range(G):
            idx = gy * G + gx
            x_center = (gx + 0.5) * cell_size
            display_gy = G - 1 - gy 
            y_center = (display_gy + 0.5) * cell_size
            ax.text(
                x_center,
                y_center,
                str(idx),
                ha='center',
                va='center',
                fontsize=6,
                color='red'
            )

    ax.set_xlim(0, image_size)
    ax.set_ylim(0, image_size)
    ax.set_xticks([])
    ax.set_yticks([])
    ax.set_title(f"{G}×{G} Grid (row‐major) with Cell Indices 0 to {G*G-1}")
    plt.tight_layout()
    plt.show()

# %%
visualize_grid_indices(G=G, image_size=256)

# %%
T = len(all_types)
total_feats = X_raw.shape[1]


G = int(math.sqrt(total_feats / (2 * T)))
# assert 2 * T * G * G == total_feats, "Unexpected feature‐count; need area+count with 2*T*G^2 == total_feats"


colnames = []

for t in all_types:
    for cell_idx in range(G * G):
        colnames.append(f"{t}_area_cell{cell_idx}")


for t in all_types:
    for cell_idx in range(G * G):
        colnames.append(f"{t}_count_cell{cell_idx}")

assert len(colnames) == total_feats

# %%
df_feats = pd.DataFrame(X_raw, index=filenames, columns=colnames)
print(df_feats.iloc[:3, :8])

scaler = StandardScaler()
X_scaled = scaler.fit_transform(df_feats.values)

df_scaled = pd.DataFrame(X_scaled, index=filenames, columns=colnames)
print(df_scaled.iloc[:3, :8])
# Out:
#            common_room_area_cell0  common_room_area_cell1  \
# 2612.png                      0.0                0.034332
# 40808.png                     0.0                0.026535
# 36358.png                     0.0                0.035889
#
#            common_room_area_cell2  common_room_area_cell3  \
# 2612.png                      0.0                     0.0
# 40808.png                     0.0                     0.0
# 36358.png                     0.0                     0.0
#
#            master_room_area_cell0  master_room_area_cell1  \
# 2612.png                  0.00000                     0.0
# 40808.png                 0.00000                     0.0
# 36358.png                 0.05127                     0.0
#
#            master_room_area_cell2  master_room_area_cell3
# 2612.png                 0.037209                0.000000
# 40808.png                0.037842                0.022621
# 36358.png                0.000000                0.000000
#            common_room_area_cell0  common_room_area_cell1  \
# 2612.png                -0.836104                1.204870
# 40808.png               -0.836104                0.751995
# 36358.png               -0.836104                1.295268
#
#            common_room_area_cell2  common_room_area_cell3  \
# 2612.png                -0.551378               -0.539154
# 40808.png               -0.551378               -0.539154
# 36358.png               -0.551378               -0.539154
#
#            master_room_area_cell0  master_room_area_cell1  \
# 2612.png                -0.363435               -0.352337
# 40808.png               -0.363435               -0.352337
# 36358.png                3.279974               -0.352337
#
#            master_room_area_cell2  master_room_area_cell3
# 2612.png                 1.001864               -0.731852
# 40808.png                1.032166                0.357026
# 36358.png               -0.778681               -0.731852

# %%
# with open("raw_feat_all_standard_quadron.pkl", "wb") as f:
#     pickle.dump(X_scaled, f)

# %%
X_scaled = pickle.load(open("raw_feat_all_standard_quadron.pkl", "rb"))

# %%
pca64 = PCA(n_components=64, random_state=0)
X_pca64 = pca64.fit_transform(X_scaled)

# %%
linkage_matrix = sch.linkage(X_pca64[:40000], method='ward')

# %%
sch.dendrogram(linkage_matrix, truncate_mode='level', p=10)
plt.ylabel("Ward distance")
plt.show()

# %%
clusterer = AgglomerativeClustering(n_clusters=12, linkage='ward')
labels = clusterer.fit_predict(X_pca64[:40000])

# %%
joblib.dump(clusterer, 'agglo_40k_clusterer_quadron.joblib')
joblib.dump((X_pca64[:40000], labels), 'X40k_and_labels_quadron.joblib')
# Out:
# ['X40k_and_labels_quadron.joblib']

# %%
clusterer = joblib.load('agglo_40k_clusterer_quadron.joblib')
X_first40k, labels = joblib.load('X40k_and_labels_quadron.joblib')

# %%
knn = KNeighborsClassifier(n_neighbors=1)
knn.fit(X_pca64[:40000], labels)
# Out:
# KNeighborsClassifier(n_neighbors=1)

# %%
X_rest = X_pca64[40000:]
labels_rest = knn.predict(X_rest)

# %%
num_data = 40000
plt.figure(figsize=(8, 6))
scatter = plt.scatter(
    X_pca64[:num_data, 0],
    X_pca64[:num_data, 3],
    c=(list(labels) + list(labels_rest))[:num_data],
    cmap="tab10",
    s=15,
    alpha=0.6
)
plt.xlabel("PC1")
plt.ylabel("PC2")
plt.title("PCA Projection of Floorplans (colored by cluster)")
plt.legend(*scatter.legend_elements(), title="Cluster")
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 6
#       1 num_data = 40000
#       2 plt.figure(figsize=(8, 6))
#       3 scatter = plt.scatter(
#       4     X_pca64[:num_data, 0],
#       5     X_pca64[:num_data, 3],
# ----> 6     c=(list(labels) + list(labels_rest))[:num_data],
#       7     cmap="tab10",
#       8     s=15,
#       9     alpha=0.6
#      10 )
#      11 plt.xlabel("PC1")
#      12 plt.ylabel("PC2")
#
# NameError: name 'labels_rest' is not defined

# %%
# cnt = Counter(list(labels) + list(labels_rest))
cnt = Counter(list(labels))
for lbl, count in sorted(cnt.items()):
    if lbl == -1:
        print(f"  Noise points: {count}")
    else:
        print(f"  Cluster {lbl:>2}: {count} plans")
# Out:
#   Cluster  0: 6826 plans
#   Cluster  1: 7260 plans
#   Cluster  2: 4896 plans
#   Cluster  3: 7140 plans
#   Cluster  4: 5974 plans
#   Cluster  5: 516 plans
#   Cluster  6: 6249 plans
#   Cluster  7: 213 plans
#   Cluster  8: 496 plans
#   Cluster  9: 89 plans
#   Cluster 10: 235 plans
#   Cluster 11: 106 plans

# %%
X_scaled[:num_data, :].shape
# Out:
# (40000, 64)

# %%
k_final = 12
num_data = 40000
cluster_centroids_16 = np.zeros((k_final, X_scaled.shape[1]), dtype=float)
X_first_n = X_scaled[:num_data]
for k in range(k_final):
    members = (labels == k)
    if np.any(members):
        cluster_centroids_16[k] = X_first_n[members].mean(axis=0)
    else:
        cluster_centroids_16[k] = 0.0

# %%
topn = 10
top_features_per_cluster = {}
for k in range(k_final):
    centroid_vals = cluster_centroids_16[k]
    top_indices = np.argsort(centroid_vals)[-topn:][::-1]
    top_features = [(colnames[idx], centroid_vals[idx]) for idx in top_indices]
    top_features_per_cluster[k] = top_features

    print(f"\nCluster {k} — top {topn} features (feature_name, z‐score):")
    for feat_name, zval in top_features:
        print(f"  {feat_name:30s}  {zval:6.2f}")
# Out:
# Cluster 0 — top 10 features (feature_name, z‐score):
#   master_room_count_cell1           1.63
#   kitchen_count_cell2               1.60
#   master_room_area_cell1            1.59
#   kitchen_area_cell2                1.50
#   storage_count_cell3               0.42
#   storage_count_cell2               0.39
#   balcony_area_cell0                0.33
#   common_room_count_cell3           0.33
#   storage_area_cell3                0.31
#   bathroom_area_cell3               0.30
#
# Cluster 1 — top 10 features (feature_name, z‐score):
#   master_room_count_cell2           1.20
#   master_room_area_cell2            1.18
#   living_room_count_cell1           1.11
#   living_room_area_cell1            1.08
#   common_room_area_cell3            0.61
#   common_room_count_cell3           0.55
#   kitchen_count_cell1               0.43
#   kitchen_area_cell1                0.38
#   bathroom_count_cell0              0.33
#   bathroom_area_cell0               0.31
#
# Cluster 2 — top 10 features (feature_name, z‐score):
#   master_room_count_cell0           1.94
#   master_room_area_cell0            1.87
#   kitchen_count_cell3               1.85
#   kitchen_area_cell3                1.69
#   balcony_area_cell1                0.50
#   common_room_count_cell2           0.50
#   common_room_area_cell2            0.45
#   balcony_count_cell1               0.35
#   bathroom_count_cell2              0.29
#   bathroom_area_cell2               0.27
#
# Cluster 3 — top 10 features (feature_name, z‐score):
#   master_room_count_cell3           1.28
#   master_room_area_cell3            1.25
#   living_room_count_cell0           1.08
#   living_room_area_cell0            1.06
#   common_room_area_cell2            0.65
#   common_room_count_cell2           0.58
#   kitchen_count_cell0               0.45
#   kitchen_area_cell0                0.42
#   bathroom_count_cell1              0.38
#   bathroom_area_cell1               0.35
#
# Cluster 4 — top 10 features (feature_name, z‐score):
#   living_room_count_cell2           1.73
#   living_room_area_cell2            1.71
#   master_room_count_cell3           1.19
#   master_room_area_cell3            1.14
#   common_room_count_cell1           0.99
#   common_room_area_cell1            0.98
#   kitchen_count_cell0               0.87
#   kitchen_area_cell0                0.79
#   bathroom_count_cell1              0.57
#   bathroom_area_cell1               0.54
#
# Cluster 5 — top 10 features (feature_name, z‐score):
#   storage_count_cell0               8.76
#   storage_area_cell0                7.01
#   kitchen_area_cell1                0.19
#   balcony_area_cell3                0.17
#   master_room_area_cell2            0.17
#   master_room_count_cell2           0.17
#   living_room_area_cell3            0.15
#   kitchen_count_cell1               0.14
#   balcony_count_cell3               0.14
#   living_room_count_cell3           0.13
#
# Cluster 6 — top 10 features (feature_name, z‐score):
#   living_room_count_cell3           1.63
#   living_room_area_cell3            1.62
#   master_room_count_cell2           1.19
#   master_room_area_cell2            1.15
#   common_room_area_cell0            1.01
#   common_room_count_cell0           1.01
#   kitchen_count_cell1               0.85
#   kitchen_area_cell1                0.77
#   bathroom_count_cell0              0.55
#   bathroom_area_cell0               0.52
#
# Cluster 7 — top 10 features (feature_name, z‐score):
#   dining_count_cell0               13.30
#   dining_area_cell0                12.10
#   kitchen_count_cell0               0.62
#   master_room_area_cell3            0.62
#   master_room_count_cell3           0.58
#   kitchen_area_cell0                0.51
#   bathroom_area_cell1               0.34
#   living_room_count_cell2           0.33
#   common_room_area_cell1            0.24
#   bathroom_count_cell1              0.23
#
# Cluster 8 — top 10 features (feature_name, z‐score):
#   storage_count_cell1               8.84
#   storage_area_cell1                7.12
#   living_room_area_cell2            0.12
#   living_room_area_cell3            0.12
#   kitchen_area_cell0                0.11
#   master_room_area_cell3            0.11
#   master_room_count_cell3           0.10
#   kitchen_area_cell1                0.09
#   living_room_count_cell2           0.08
#   bathroom_area_cell0               0.07
#
# Cluster 9 — top 10 features (feature_name, z‐score):
#   dining_count_cell3               21.28
#   dining_area_cell3                17.75
#   kitchen_count_cell3               1.76
#   kitchen_area_cell3                1.64
#   master_room_area_cell0            1.39
#   master_room_count_cell0           1.33
#   bathroom_area_cell3               0.38
#   bathroom_area_cell2               0.32
#   storage_count_cell0               0.28
#   living_room_count_cell2           0.28
#
# Cluster 10 — top 10 features (feature_name, z‐score):
#   dining_count_cell1               13.06
#   dining_area_cell1                12.03
#   kitchen_count_cell1               0.55
#   kitchen_area_cell1                0.50
#   master_room_area_cell2            0.47
#   master_room_count_cell2           0.39
#   bathroom_area_cell0               0.25
#   living_room_count_cell3           0.22
#   common_room_area_cell0            0.21
#   storage_count_cell2               0.20
#
# Cluster 11 — top 10 features (feature_name, z‐score):
#   dining_count_cell2               19.68
#   dining_area_cell2                17.70
#   kitchen_count_cell2               1.77
#   kitchen_area_cell2                1.49
#   master_room_area_cell1            1.38
#   master_room_count_cell1           1.28
#   master_room_area_cell0            0.46
#   master_room_count_cell0           0.43
#   storage_area_cell0                0.42
#   storage_count_cell0               0.30

# %%
N = 10
under_features_per_cluster = {}

for k in range(k_final):
    centroid_vals = cluster_centroids_16[k]

    neg_indices = np.argsort(centroid_vals)[:N]
    neg_feats = [(colnames[idx], centroid_vals[idx]) for idx in neg_indices]
    under_features_per_cluster[k] = neg_feats

    print(f"\nCluster {k} — top {N} under‐represented features (name, z‐score):")
    for feat_name, zval in neg_feats:
        print(f"  {feat_name:30s} {zval:6.2f}")
# Out:
# Cluster 0 — top 10 under‐represented features (name, z‐score):
#   kitchen_count_cell1             -0.68
#   master_room_count_cell2         -0.68
#   master_room_area_cell2          -0.66
#   kitchen_area_cell1              -0.63
#   master_room_count_cell3         -0.43
#   master_room_area_cell3          -0.42
#   kitchen_count_cell0             -0.39
#   kitchen_area_cell0              -0.35
#   living_room_count_cell1         -0.35
#   living_room_area_cell1          -0.34
#
# Cluster 1 — top 10 under‐represented features (name, z‐score):
#   master_room_count_cell3         -0.73
#   master_room_area_cell3          -0.71
#   living_room_count_cell3         -0.60
#   living_room_area_cell3          -0.59
#   living_room_count_cell2         -0.55
#   living_room_area_cell2          -0.54
#   common_room_count_cell1         -0.43
#   common_room_area_cell1          -0.43
#   master_room_count_cell0         -0.37
#   kitchen_count_cell3             -0.36
#
# Cluster 2 — top 10 under‐represented features (name, z‐score):
#   kitchen_count_cell0             -0.65
#   master_room_count_cell3         -0.65
#   master_room_area_cell3          -0.63
#   kitchen_area_cell0              -0.61
#   master_room_count_cell2         -0.41
#   living_room_count_cell0         -0.41
#   master_room_area_cell2          -0.41
#   living_room_area_cell0          -0.40
#   master_room_count_cell1         -0.35
#   kitchen_count_cell1             -0.35
#
# Cluster 3 — top 10 under‐represented features (name, z‐score):
#   master_room_count_cell2         -0.78
#   master_room_area_cell2          -0.76
#   living_room_count_cell2         -0.57
#   living_room_area_cell2          -0.56
#   living_room_count_cell3         -0.52
#   living_room_area_cell3          -0.50
#   common_room_area_cell0          -0.45
#   common_room_count_cell0         -0.45
#   master_room_count_cell0         -0.37
#   kitchen_count_cell3             -0.36
#
# Cluster 4 — top 10 under‐represented features (name, z‐score):
#   master_room_count_cell2         -0.70
#   master_room_area_cell2          -0.68
#   living_room_count_cell3         -0.61
#   living_room_area_cell3          -0.60
#   living_room_count_cell1         -0.57
#   living_room_area_cell1          -0.55
#   living_room_count_cell0         -0.55
#   living_room_area_cell0          -0.54
#   balcony_count_cell3             -0.41
#   bathroom_count_cell2            -0.40
#
# Cluster 5 — top 10 under‐represented features (name, z‐score):
#   balcony_count_cell0             -0.27
#   balcony_area_cell0              -0.22
#   balcony_area_cell1              -0.18
#   balcony_count_cell1             -0.18
#   bathroom_count_cell3            -0.17
#   bathroom_area_cell3             -0.17
#   living_room_count_cell0         -0.15
#   balcony_count_cell2             -0.15
#   master_room_count_cell0         -0.15
#   master_room_area_cell0          -0.14
#
# Cluster 6 — top 10 under‐represented features (name, z‐score):
#   master_room_count_cell3         -0.74
#   master_room_area_cell3          -0.72
#   living_room_count_cell2         -0.58
#   living_room_count_cell1         -0.57
#   living_room_area_cell2          -0.56
#   living_room_area_cell1          -0.55
#   living_room_count_cell0         -0.55
#   living_room_area_cell0          -0.54
#   common_room_area_cell1          -0.41
#   balcony_count_cell2             -0.41
#
# Cluster 7 — top 10 under‐represented features (name, z‐score):
#   common_room_count_cell0         -0.61
#   common_room_area_cell0          -0.60
#   kitchen_count_cell3             -0.35
#   master_room_count_cell0         -0.35
#   master_room_area_cell0          -0.34
#   kitchen_area_cell3              -0.33
#   bathroom_count_cell0            -0.32
#   balcony_count_cell0             -0.31
#   kitchen_count_cell1             -0.30
#   balcony_area_cell0              -0.29
#
# Cluster 8 — top 10 under‐represented features (name, z‐score):
#   balcony_count_cell1             -0.25
#   balcony_area_cell1              -0.22
#   living_room_count_cell1         -0.20
#   balcony_count_cell0             -0.19
#   living_room_area_cell1          -0.19
#   balcony_area_cell0              -0.18
#   balcony_count_cell3             -0.17
#   master_room_area_cell1          -0.17
#   master_room_count_cell1         -0.16
#   bathroom_count_cell2            -0.16
#
# Cluster 9 — top 10 under‐represented features (name, z‐score):
#   master_room_count_cell3         -0.68
#   master_room_area_cell3          -0.66
#   balcony_count_cell3             -0.65
#   kitchen_count_cell0             -0.64
#   balcony_area_cell3              -0.59
#   kitchen_area_cell0              -0.57
#   kitchen_count_cell1             -0.41
#   bathroom_count_cell0            -0.33
#   kitchen_area_cell1              -0.32
#   balcony_count_cell2             -0.31
#
# Cluster 10 — top 10 under‐represented features (name, z‐score):
#   common_room_count_cell1         -0.51
#   common_room_area_cell1          -0.48
#   master_room_count_cell1         -0.32
#   balcony_count_cell1             -0.32
#   master_room_area_cell1          -0.32
#   kitchen_count_cell2             -0.31
#   kitchen_count_cell0             -0.31
#   living_room_area_cell1          -0.27
#   balcony_area_cell1              -0.25
#   bathroom_count_cell1            -0.25
#
# Cluster 11 — top 10 under‐represented features (name, z‐score):
#   master_room_count_cell2         -0.76
#   master_room_area_cell2          -0.73
#   kitchen_count_cell1             -0.72
#   kitchen_area_cell1              -0.65
#   balcony_count_cell2             -0.53
#   balcony_area_cell2              -0.49
#   kitchen_count_cell0             -0.48
#   balcony_count_cell3             -0.47
#   kitchen_area_cell0              -0.43
#   master_room_count_cell3         -0.36

# %%
cosim_matrix = cosine_similarity(X_scaled, cluster_centroids_16) 
cosim_matrix.shape

cosim_colnames = [f"cos_sim_{k}" for k in range(k_final)]
df_cosim = pd.DataFrame(cosim_matrix, index=filenames, columns=cosim_colnames)

df_features = pd.DataFrame(X_scaled, index=filenames, columns=colnames)

# %%
df_result = pd.concat([df_cosim, df_features, ], axis=1)[:num_data]
df_result['cluster'] = labels

# %%
df_result = df_result[[df_result.columns[-1]] + list(df_result.columns[:-1])]

# %%
df_result.to_csv("raw_feat_cluster_results_quadron.csv")
